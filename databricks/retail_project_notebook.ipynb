# %% [markdown]
# ##                               Read data on Bronze layer

# %%
spark.conf.set("fs.azure.account.key.retaildemoproject01.blob.core.windows.net",
               "cLd9yYvzYmLq/TxpWdmeQx0QFyGhDHLt2bZU7Eaw+WSiZKKo9wMFoS0Gqa/iGRrj2+MGCA1xn/eZ+AStvMPNdQ==")

df = spark.read.format("parquet").load(
    "wasbs://retail@retaildemoproject01.blob.core.windows.net/")

# %%
dbutils.fs.ls("wasbs://retail@retaildemoproject01.blob.core.windows.net/bronze/transaction")
# Out:
# [FileInfo(path='wasbs://retail@retaildemoproject01.blob.core.windows.net/bronze/transaction/dbo.transactions.parquet', name='dbo.transactions.parquet', size=1757, modificationTime=1763990319000)]

# %%
df_transaction= spark.read.parquet("wasbs://retail@retaildemoproject01.blob.core.windows.net/bronze/transaction")
df_product= spark.read.parquet("wasbs://retail@retaildemoproject01.blob.core.windows.net/bronze/product")
df_store= spark.read.parquet("wasbs://retail@retaildemoproject01.blob.core.windows.net/bronze/store")
df_customers=spark.read.parquet("wasbs://retail@retaildemoproject01.blob.core.windows.net/bronze/customer/manish040596/azure-data-engineer---multi-source/refs/heads/main/")
display(df_customers)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# ## Create Silver Layer- **DATA CLEANING**

# %%
from  pyspark.sql.functions import col

#convert types and data cleaning
df_transaction= df_transaction.select(
    col("transaction_id").cast("int"),
    col("customer_id").cast("int"),
    col("product_id").cast("int"),
    col("store_id").cast("int"),
    col("transaction_date").cast("date"),
    col("quantity").cast("int")
)

df_product= df_product.select(
    col("product_id").cast("int"),
    col("product_name"),
    col("category"),
    col("price").cast("double")
)

df_store= df_store.select(
    col("store_id").cast("int"),
    col("store_name"),
    col("location")
)
df_customers= df_customers.select(
    "customer_id","first_name", "last_name","email","city","registration_date"
).dropDuplicates(['customer_id'])

# %% [markdown]
#  #JOIN ALL DATA TOGETHER

# %%
# DBTITLE 1,join all data together
# Join all data
df_silver = df_transaction \
    .join(df_customers, "customer_id") \
    .join(df_product, "product_id") \
    .join(df_store, "store_id") \
    .withColumn("total_amount", col("quantity") * col("price"))

# %%
display(df_silver)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
silver_path="wasbs://retail@retaildemoproject01.blob.core.windows.net/silver/"
df_silver.write.mode("overwrite").format("delta").save(silver_path)

# %%
silver_path = "wasbs://retail@retaildemoproject01.blob.core.windows.net/silver/"

df_silver = spark.read.format("delta").load(silver_path)
df_silver.createOrReplaceTempView("retail_silver_cleaned")

# %%
display(df_silver)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
SELECT * FROM retail_silver_cleaned
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
from pyspark.sql.functions import sum, countDistinct, avg

gold_df = df_silver.groupBy(
    "transaction_date",
    "product_id", "product_name", "category",
    "store_id", "store_name", "location"
).agg(
    sum("quantity").alias("total_quantity_sold"),
    sum("total_amount").alias("total_sales_amount"),
    countDistinct("transaction_id").alias("number_of_transactions"),
    avg("total_amount").alias("average_transaction_value")
)

# %%
display(gold_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
gold_path = "wasbs://retail@retaildemoproject01.blob.core.windows.net/gold/"
gold_df.write.format("delta").mode("overwrite").save(gold_path)

# %%
gold_path = "wasbs://retail@retaildemoproject01.blob.core.windows.net/gold/"

df_gold = spark.read.format("delta").load(gold_path)
df_gold.createOrReplaceTempView("retail_gold_summary")

# %%
# %sql
SELECT * FROM retail_gold_summary
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
